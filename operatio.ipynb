# %%
a = [ ]
print(a)
print(type(a))
# Out:
# []
# <class 'list'>

# %%
c = [ 10 , 20 , 30 , 40 , 50]
print(c[1:4])
# Out:
# [20, 30, 40]

# %%
d = [ 1,2,3,4,5]
print("before append" ,d)
d.append(6)
print("after append" ,d)
# Out:
# before append [1, 2, 3, 4, 5]
# after append [1, 2, 3, 4, 5, 6]

# %%
e = [1,2,3,4]
print("before extend" , e)
e.extend([ "ram" , 9, "eat"])
print("after extend" , e)
# Out:
# before extend [1, 2, 3, 4]
# after extend [1, 2, 3, 4, 'ram', 9, 'eat']
